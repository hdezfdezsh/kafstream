# %%
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream
import tweepy
from kafka import SimpleProducer, KafkaClient

# %%
access_token="1096817153922207745-57xWqLtjSTcm214A4NQBznvVt0ANuh"
access_token_secret="2IxtqD2KlBTFx6nYSaqCrkXKuixGxr3xWz4AvCvujQIoo"
consumer_key="BvNFYpaA6OMnT9jdO4L8G8yBj"
consumer_secret="F5hzJYIFqLA17TUbzwAt7l6lkWWkHPBdq69ccqvPzUNvW6V5JG"

# %%
class StdOutListener(StreamListener):
    def __init__(self):
        kafka = KafkaClient("localhost:9092")
        self.producer = SimpleProducer(kafka)
    def on_data(self, data):
        self.producer.send_messages("prueba2", data.encode('utf-8'))
        print (data)
        return True
    def on_error(self, status):
        print (status)

# %%
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)
stream = Stream(auth, StdOutListener())
stream.filter(track=['#trump'])
# Out:
# {"created_at":"Mon Mar 04 12:06:58 +0000 2019","id":1102540937824223238,"id_str":"1102540937824223238","text":"RT @Tombx7M: When you beat the Democrats you\u2019re a racist\n#Tcot #ccot #FoxandFriends #WWG1WGA  #Trump\n#MAGA  #Morningjoe #KAG https:\/\/t.co\/d\u2026","source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":431038127,"id_str":"431038127","name":"De","screen_name":"chestersadie","location":"Mars","url":null,"description":null,"translator_type":"none","protected":false,"verified":false,"followers_count":146,"friends_count":326,"listed_count":0,"favourites_count":14009,"statuses_count":17646,"created_at":"Wed Dec 07 21:08:01 +0000 2011","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":"en","contributors_enabled":fa
# ...
